# %% [markdown]
# # Frequent Pattern Mining

# %%
from pyspark.sql import SQLContext
from pyspark import SparkContext, SparkConf
conf = SparkConf().setAppName("Frequent Pattern Mining")
sc = SparkContext(conf=conf)
sqlContext = SQLContext(sc)

# %%
from pyspark.ml.fpm import FPGrowth

# %%
df=sqlContext.createDataFrame([
    (0, [1, 2, 5]),
    (1, [1, 2, 3, 5]),
    (2, [1, 2])
], ["id", "items"])

# %%
df.collect()
# Out:
# [Row(id=0, items=[1, 2, 5]),
#  Row(id=1, items=[1, 2, 3, 5]),
#  Row(id=2, items=[1, 2])]

# %%
fpGrowth = FPGrowth(itemsCol="items", minSupport=0.5, minConfidence=0.6)
model = fpGrowth.fit(df)

# %%
# Display frequent itemsets.
model.freqItemsets.show()
# Out:
# +---------+----+
# |    items|freq|
# +---------+----+
# |      [1]|   3|
# |      [2]|   3|
# |   [2, 1]|   3|
# |      [5]|   2|
# |   [5, 2]|   2|
# |[5, 2, 1]|   2|
# |   [5, 1]|   2|
# +---------+----+

# %%
# Display generated association rules.
model.associationRules.show()
# Out:
# +----------+----------+------------------+
# |antecedent|consequent|        confidence|
# +----------+----------+------------------+
# |    [5, 2]|       [1]|               1.0|
# |       [2]|       [1]|               1.0|
# |       [2]|       [5]|0.6666666666666666|
# |    [2, 1]|       [5]|0.6666666666666666|
# |       [5]|       [2]|               1.0|
# |       [5]|       [1]|               1.0|
# |    [5, 1]|       [2]|               1.0|
# |       [1]|       [2]|               1.0|
# |       [1]|       [5]|0.6666666666666666|
# +----------+----------+------------------+

# %%
# transform examines the input items against all the association rules and summarize the
# consequents as prediction
model.transform(df).show()
# Out:
# +---+------------+----------+
# | id|       items|prediction|
# +---+------------+----------+
# |  0|   [1, 2, 5]|        []|
# |  1|[1, 2, 3, 5]|        []|
# |  2|      [1, 2]|       [5]|
# +---+------------+----------+

# %%
new=sqlContext.createDataFrame([
    (4, [1])
], ["id", "items"])

model.transform(new).show()
# Out:
# +---+-----+----------+
# | id|items|prediction|
# +---+-----+----------+
# |  4|  [1]|    [2, 5]|
# +---+-----+----------+

# %% [markdown]
# # Applying Real Time data (supermarket)

# %%
# !ls
# Out:
# Frequent Pattern Mining.ipynb  Market_Basket_Optimisation.csv

# %%
filename = "Market_Basket_Optimisation.csv"

# %%
items=[]
file = open(filename, "r")
for line in file:
    for i in line.split(","):
        items.append(i.rstrip())

# %%
id_to_name={}
for i,item in enumerate(set(items)):
    id_to_name[i]=item
print(id_to_name)
# Out:
# {0: 'champagne', 1: 'mayonnaise', 2: 'cider', 3: 'candy bars', 4: 'fresh bread', 5: 'nonfat milk', 6: 'red wine', 7: 'bacon', 8: 'pet food', 9: 'mint', 10: 'pancakes', 11: 'chili', 12: 'toothpaste', 13: 'tomato juice', 14: 'cottage cheese', 15: 'salmon', 16: 'white wine', 17: 'barbecue sauce', 18: 'chocolate', 19: 'parmesan cheese', 20: 'napkins', 21: 'strawberries', 22: 'ketchup', 23: 'carrots', 24: 'frozen vegetables', 25: 'magazines', 26: 'chicken', 27: 'french fries', 28: 'almonds', 29: 'avocado', 30: 'mushroom cream sauce', 31: 'pepper', 32: 'cream', 33: 'chutney', 34: 'cake', 35: 'corn', 36: 'burger sauce', 37: 'honey', 38: 'meatballs', 39: 'fresh tuna', 40: 'mint green tea', 41: 'eggs', 42: 'bug spray', 43: 'tea', 44: 'green grapes', 45: 'antioxydant juice', 46: 'sparkling water', 47: 'frozen smoothie', 48: 'bramble', 49: 'energy drink', 50: 'cooking oil', 51: 'dessert wine', 52: 'strong cheese', 53: 'oatmeal', 54: 'asparagus', 55: 'black tea', 56: 'mineral water', 57: 'energy bar', 58: 'cookies', 59: 'eggplant', 60: ' asparagus', 61: 'flax seed', 62: 'green beans', 63: 'body spray', 64: 'olive oil', 65: 'chocolate bread', 66: 'soda', 67: 'herb & pepper', 68: 'mashed potato', 69: 'blueberries', 70: 'vegetables mix', 71: 'shrimp', 72: 'gums', 73: 'french wine', 74: 'grated cheese', 75: 'butter', 76: 'green tea', 77: 'water spray', 78: 'spinach', 79: 'low fat yogurt', 80: 'pasta', 81: 'salt', 82: 'rice', 83: 'spaghetti', 84: 'sandwich', 85: 'cereals', 86: 'whole weat flour', 87: 'turkey', 88: 'whole wheat pasta', 89: 'light cream', 90: 'tomatoes', 91: 'hand protein bar', 92: 'burgers', 93: 'tomato sauce', 94: 'pickles', 95: 'brownies', 96: 'ham', 97: 'fromage blanc', 98: 'babies food', 99: 'clothes accessories', 100: 'melons', 101: 'cauliflower', 102: 'gluten free bar', 103: 'shallot', 104: 'soup', 105: 'oil', 106: 'yogurt cake', 107: 'zucchini', 108: 'shampoo', 109: 'muffins', 110: 'yams', 111: 'ground beef', 112: 'extra dark chocolate', 113: 'whole wheat rice', 114: 'escalope', 115: 'light mayo', 116: 'salad', 117: 'milk', 118: 'protein bar', 119: 'hot dogs'}

# %%
name_to_id={}
for i,item in enumerate(set(items)):
    name_to_id[item]=i
print(name_to_id)
# Out:
# {'champagne': 0, 'mayonnaise': 1, 'cider': 2, 'candy bars': 3, 'fresh bread': 4, 'nonfat milk': 5, 'red wine': 6, 'bacon': 7, 'pet food': 8, 'mint': 9, 'pancakes': 10, 'chili': 11, 'toothpaste': 12, 'tomato juice': 13, 'cottage cheese': 14, 'salmon': 15, 'white wine': 16, 'barbecue sauce': 17, 'chocolate': 18, 'parmesan cheese': 19, 'napkins': 20, 'strawberries': 21, 'ketchup': 22, 'carrots': 23, 'frozen vegetables': 24, 'magazines': 25, 'chicken': 26, 'french fries': 27, 'almonds': 28, 'avocado': 29, 'mushroom cream sauce': 30, 'pepper': 31, 'cream': 32, 'chutney': 33, 'cake': 34, 'corn': 35, 'burger sauce': 36, 'honey': 37, 'meatballs': 38, 'fresh tuna': 39, 'mint green tea': 40, 'eggs': 41, 'bug spray': 42, 'tea': 43, 'green grapes': 44, 'antioxydant juice': 45, 'sparkling water': 46, 'frozen smoothie': 47, 'bramble': 48, 'energy drink': 49, 'cooking oil': 50, 'dessert wine': 51, 'strong cheese': 52, 'oatmeal': 53, 'asparagus': 54, 'black tea': 55, 'mineral water': 56, 'energy bar': 57, 'cookies': 58, 'eggplant': 59, ' asparagus': 60, 'flax seed': 61, 'green beans': 62, 'body spray': 63, 'olive oil': 64, 'chocolate bread': 65, 'soda': 66, 'herb & pepper': 67, 'mashed potato': 68, 'blueberries': 69, 'vegetables mix': 70, 'shrimp': 71, 'gums': 72, 'french wine': 73, 'grated cheese': 74, 'butter': 75, 'green tea': 76, 'water spray': 77, 'spinach': 78, 'low fat yogurt': 79, 'pasta': 80, 'salt': 81, 'rice': 82, 'spaghetti': 83, 'sandwich': 84, 'cereals': 85, 'whole weat flour': 86, 'turkey': 87, 'whole wheat pasta': 88, 'light cream': 89, 'tomatoes': 90, 'hand protein bar': 91, 'burgers': 92, 'tomato sauce': 93, 'pickles': 94, 'brownies': 95, 'ham': 96, 'fromage blanc': 97, 'babies food': 98, 'clothes accessories': 99, 'melons': 100, 'cauliflower': 101, 'gluten free bar': 102, 'shallot': 103, 'soup': 104, 'oil': 105, 'yogurt cake': 106, 'zucchini': 107, 'shampoo': 108, 'muffins': 109, 'yams': 110, 'ground beef': 111, 'extra dark chocolate': 112, 'whole wheat rice': 113, 'escalope': 114, 'light mayo': 115, 'salad': 116, 'milk': 117, 'protein bar': 118, 'hot dogs': 119}

# %%
data=[]
unique=[]
file = open(filename, "r")
for i,line in enumerate(file):
    data.append([])
    for item in line.split(","):
        unique.append(name_to_id[item.rstrip()])
    for item in set(unique):        
        data[i].append(item)
    unique=[]

# %%
arr=[]
for i,line in enumerate(data):
   arr.append((i,line))

# %%
market=sqlContext.createDataFrame((arr), ["id", "items"])

# %%
market.collect()
# Out:
# [Row(id=0, items=[64, 37, 70, 71, 78, 44, 13, 110, 14, 79, 49, 76, 15, 116, 45, 86, 47, 56, 28, 29]),
#  Row(id=1, items=[41, 92, 38]),
#  Row(id=2, items=[33]),
#  Row(id=3, items=[29, 87]),
#  Row(id=4, items=[76, 113, 117, 56, 57]),
#  Row(id=5, items=[79]),
#  Row(id=6, items=[88, 27]),
#  Row(id=7, items=[104, 89, 103]),
#  Row(id=8, items=[24, 83, 76]),
#  Row(id=9, items=[27]),
#  Row(id=10, items=[8, 41]),
#  Row(id=11, items=[58]),
#  Row(id=12, items=[41, 50, 87, 56, 92]),
#  Row(id=13, items=[0, 58, 83]),
#  Row(id=14, items=[56, 15]),
#  Row(id=15, items=[56]),
#  Row(id=16, items=[37, 71, 105, 79, 18, 50, 26]),
#  Row(id=17, items=[41, 87]),
#  Row(id=18, items=[26, 39, 41, 15, 112, 83, 55, 87, 56, 90]),
#  Row(id=19, items=[37, 38, 117, 118, 27]),
#  Row(id=20, items=[6, 71, 41, 108, 80, 18, 31]),
#  Row(id=21, items=[82, 46]),
#  Row(id=22, items=[96, 10, 76, 83, 56, 63]),
#  Row(id=23, items=[37, 71, 74, 12, 80, 16, 92, 29]),
#  Row(id=24, items=[41]),
#  Row(id=25, items=[4, 104, 83, 19, 117, 29]),
#  Row(id=26, items=[111, 15, 47, 114, 83, 117, 55, 56, 57]),
#  Row(id=27, items=[46]),
#  Row(id=28, items=[41, 18, 56, 26, 27]),
#  Row(id=29, items=[24, 56, 83, 110]),
#  Row(id=30, items=[89, 67, 93, 25]),
#  Row(id=31, items=[56, 41, 18, 29]),
#  Row(id=32, items=[27, 21, 87]),
#  Row(id=33, items=[24, 18, 52]),
#  Row(id=34, items=[58]),
#  Row(id=35, items=[114, 83, 94, 15]),
#  Row(id=36, items=[57, 27]),
#  Row(id=37, items=[56, 6, 111]),
#  Row(id=38, items=[56, 34, 14]),
#  Row(id=39, items=[0, 76, 94]),
#  Row(id=40, items=[83]),
#  Row(id=41, items=[37, 39, 47, 113, 114, 83, 24, 56]),
#  Row(id=42, items=[83]),
#  Row(id=43, items=[104, 46, 38, 119]),
#  Row(id=44, items=[114]),
#  Row(id=45, items=[104, 10, 76, 63, 119, 27, 29, 95]),
#  Row(id=46, items=[56, 26, 99, 85]),
#  Row(id=47, items=[56, 42]),
#  Row(id=48, items=[109, 29]),
#  Row(id=49, items=[92, 76, 55]),
#  Row(id=50, items=[76, 16, 18, 83, 95]),
#  Row(id=51, items=[56, 41, 39]),
#  Row(id=52, items=[83, 109]),
#  Row(id=53, items=[18, 83]),
#  Row(id=54, items=[0, 114, 27]),
#  Row(id=55, items=[115, 93]),
#  Row(id=56, items=[64, 56, 39, 104, 111, 18, 83, 117, 87, 24, 90]),
#  Row(id=57, items=[41, 58]),
#  Row(id=58, items=[66, 104, 72, 76, 49, 26, 63]),
#  Row(id=59, items=[2, 76, 50, 87, 24, 56]),
#  Row(id=60, items=[83]),
#  Row(id=61, items=[99]),
#  Row(id=62, items=[49]),
#  Row(id=63, items=[103, 104, 42, 76, 118]),
#  Row(id=64, items=[41, 87]),
#  Row(id=65, items=[27]),
#  Row(id=66, items=[18, 117]),
#  Row(id=67, items=[2, 67, 111, 113, 88, 56, 29]),
#  Row(id=68, items=[58]),
#  Row(id=69, items=[80, 71]),
#  Row(id=70, items=[35, 67, 74, 90, 93]),
#  Row(id=71, items=[114, 92, 103]),
#  Row(id=72, items=[58]),
#  Row(id=73, items=[106]),
#  Row(id=74, items=[104, 41]),
#  Row(id=75, items=[58]),
#  Row(id=76, items=[56, 18, 79]),
#  Row(id=77, items=[41, 21]),
#  Row(id=78, items=[74, 111, 16, 83, 56]),
#  Row(id=79, items=[9]),
#  Row(id=80, items=[41, 34, 27]),
#  Row(id=81, items=[76, 83, 117, 27, 92]),
#  Row(id=82, items=[56, 57, 75, 27]),
#  Row(id=83, items=[67, 41, 74, 50, 56, 92]),
#  Row(id=84, items=[57]),
#  Row(id=85, items=[57, 49]),
#  Row(id=86, items=[18, 47]),
#  Row(id=87, items=[79]),
#  Row(id=88, items=[116, 54]),
#  Row(id=89, items=[27, 92, 76, 79]),
#  Row(id=90, items=[79]),
#  Row(id=91, items=[64, 67, 38, 71, 73, 41, 80, 81, 83, 56, 57, 92]),
#  Row(id=92, items=[0, 79]),
#  Row(id=93, items=[0]),
#  Row(id=94, items=[41, 76, 28, 58, 27, 92]),
#  Row(id=95, items=[96, 114, 104, 63]),
#  Row(id=96, items=[96, 105, 43, 112, 87, 24, 25, 31]),
#  Row(id=97, items=[41, 58, 109]),
#  Row(id=98, items=[58]),
#  Row(id=99, items=[76, 111, 18, 83, 24, 88]),
#  Row(id=100, items=[56, 17, 18]),
#  Row(id=101, items=[1, 67, 35, 41, 107, 28, 57, 92]),
#  Row(id=102, items=[104, 41, 28, 14, 111, 18, 119, 87, 92]),
#  Row(id=103, items=[96, 41, 18, 83]),
#  Row(id=104, items=[8, 111, 118, 23, 57]),
#  Row(id=105, items=[41, 111, 83, 56, 28, 93]),
#  Row(id=106, items=[56, 72, 50, 64]),
#  Row(id=107, items=[64, 71, 104, 41, 42, 44, 80, 117, 56, 29]),
#  Row(id=108, items=[34, 71, 104, 79, 80, 50, 115, 26]),
#  Row(id=109, items=[0, 4, 18, 83, 114, 56, 27, 30]),
#  Row(id=110, items=[80, 41, 56, 71]),
#  Row(id=111, items=[105, 4, 92, 13]),
#  Row(id=112, items=[73, 18, 79, 41]),
#  Row(id=113, items=[10, 41, 26, 27]),
#  Row(id=114, items=[3, 67, 15, 16, 87]),
#  Row(id=115, items=[64, 41, 74, 76, 83, 27]),
#  Row(id=116, items=[56, 57]),
#  Row(id=117, items=[41, 27]),
#  Row(id=118, items=[104, 41, 28, 13, 18, 117, 56, 90, 92]),
#  Row(id=119, items=[109]),
#  Row(id=120, items=[80]),
#  Row(id=121, items=[90, 83, 47]),
#  Row(id=122, items=[83, 117, 111]),
#  Row(id=123, items=[27]),
#  Row(id=124, items=[18, 117]),
#  Row(id=125, items=[71, 41, 10, 79, 80, 18, 83, 117, 24, 56, 27, 92]),
#  Row(id=126, items=[56, 45, 118, 111]),
#  Row(id=127, items=[34, 74, 111, 49, 83, 88]),
#  Row(id=128, items=[74]),
#  Row(id=129, items=[10]),
#  Row(id=130, items=[47]),
#  Row(id=131, items=[76, 23]),
#  Row(id=132, items=[18]),
#  Row(id=133, items=[64, 35, 41, 18, 50, 87, 92]),
#  Row(id=134, items=[26, 4, 90, 10, 11, 43, 13, 83, 24, 56, 27, 31]),
#  Row(id=135, items=[58]),
#  Row(id=136, items=[111]),
#  Row(id=137, items=[41, 13, 47, 18, 87]),
#  Row(id=138, items=[24, 50, 68]),
#  Row(id=139, items=[64, 38, 13, 111, 24, 89, 56, 93]),
#  Row(id=140, items=[34, 6, 104, 41, 72, 47, 50, 83, 18, 117, 56]),
#  Row(id=141, items=[64, 41, 18, 83, 82, 117, 56, 90, 27, 29, 95]),
#  Row(id=142, items=[5, 71, 41, 111, 80, 18, 24, 56]),
#  Row(id=143, items=[71, 41, 80, 83, 87, 56, 26, 27, 31]),
#  Row(id=144, items=[58]),
#  Row(id=145, items=[90, 34, 87]),
#  Row(id=146, items=[0, 104, 10, 110, 113, 17, 18, 117, 23, 56]),
#  Row(id=147, items=[82]),
#  Row(id=148, items=[18, 117]),
#  Row(id=149, items=[80, 24, 77, 71]),
#  Row(id=150, items=[41, 9, 113, 117, 56, 92]),
#  Row(id=151, items=[34, 70, 47, 56, 95]),
#  Row(id=152, items=[58]),
#  Row(id=153, items=[80, 65, 26, 71]),
#  Row(id=154, items=[103]),
#  Row(id=155, items=[71, 41, 76, 80, 83, 119]),
#  Row(id=156, items=[92]),
#  Row(id=157, items=[64, 6, 111, 50, 83, 52, 117, 56, 89]),
#  Row(id=158, items=[105, 74, 83, 117, 27, 92, 29]),
#  Row(id=159, items=[64, 67, 111, 88, 56]),
#  Row(id=160, items=[71, 110, 80, 18, 117]),
#  Row(id=161, items=[75, 76]),
#  Row(id=162, items=[115]),
#  Row(id=163, items=[79]),
#  Row(id=164, items=[67, 71, 80, 83, 117]),
#  Row(id=165, items=[41, 92]),
#  Row(id=166, items=[67, 4, 104, 41, 13, 111, 17, 23, 117, 55, 87, 58, 29]),
#  Row(id=167, items=[58]),
#  Row(id=168, items=[114]),
#  Row(id=169, items=[10, 79, 21, 27, 31]),
#  Row(id=170, items=[37, 110, 115, 24, 26]),
#  Row(id=171, items=[0, 18]),
#  Row(id=172, items=[34, 67, 37, 82, 118]),
#  Row(id=173, items=[111, 18, 115, 117, 54, 24, 56, 92]),
#  Row(id=174, items=[35, 76, 14, 18, 56]),
#  Row(id=175, items=[109]),
#  Row(id=176, items=[96, 73, 114]),
#  Row(id=177, items=[40, 113, 83, 117]),
#  Row(id=178, items=[18, 63]),
#  Row(id=179, items=[24, 27, 119]),
#  Row(id=180, items=[3]),
#  Row(id=181, items=[71, 76, 80, 16, 117, 58, 27, 92]),
#  Row(id=182, items=[19, 111]),
#  Row(id=183, items=[113, 10, 3]),
#  Row(id=184, items=[41, 58, 59]),
#  Row(id=185, items=[24, 56]),
#  Row(id=186, items=[18]),
#  Row(id=187, items=[113, 18, 83, 117, 87]),
#  Row(id=188, items=[0, 69, 38, 104, 106, 111, 50, 83, 118, 88, 26]),
#  Row(id=189, items=[50, 13]),
#  Row(id=190, items=[41, 76, 117, 24, 27]),
#  Row(id=191, items=[64, 0, 39, 73, 41, 10, 83, 115, 27]),
#  Row(id=192, items=[37, 6, 119]),
#  Row(id=193, items=[4, 7, 41, 117, 27]),
#  Row(id=194, items=[106, 27]),
#  Row(id=195, items=[117]),
#  Row(id=196, items=[27]),
#  Row(id=197, items=[18]),
#  Row(id=198, items=[96, 92, 6]),
#  Row(id=199, items=[71, 73, 45, 47, 80, 57, 90, 27, 95]),
#  Row(id=200, items=[76]),
#  Row(id=201, items=[79]),
#  Row(id=202, items=[66, 104, 78, 49, 81, 83, 87, 56]),
#  Row(id=203, items=[41, 87]),
#  Row(id=204, items=[42, 119]),
#  Row(id=205, items=[105]),
#  Row(id=206, items=[34, 104, 41, 21, 57, 26, 27, 63]),
#  Row(id=207, items=[18, 83, 106]),
#  Row(id=208, items=[56, 38, 87]),
#  Row(id=209, items=[97, 7, 111, 18, 119, 56]),
#  Row(id=210, items=[24, 56, 70, 114]),
#  Row(id=211, items=[90, 67, 6]),
#  Row(id=212, items=[64, 76, 85, 88, 95]),
#  Row(id=213, items=[58]),
#  Row(id=214, items=[64, 58, 30]),
#  Row(id=215, items=[102, 10, 111, 50, 115]),
#  Row(id=216, items=[56, 27]),
#  Row(id=217, items=[67]),
#  Row(id=218, items=[15]),
#  Row(id=219, items=[41, 114]),
#  Row(id=220, items=[56, 13]),
#  Row(id=221, items=[56]),
#  Row(id=222, items=[56, 104, 55, 71]),
#  Row(id=223, items=[34, 47]),
#  Row(id=224, items=[97, 37, 74, 113, 18, 87, 90, 92]),
#  Row(id=225, items=[64, 10, 111, 24, 56]),
#  Row(id=226, items=[64, 34, 4, 111, 117, 87, 92]),
#  Row(id=227, items=[33, 104, 110, 111, 49, 83, 85, 118, 88, 56]),
#  Row(id=228, items=[34, 41, 76, 113, 114]),
#  Row(id=229, items=[104, 76, 110, 15, 111, 29]),
#  Row(id=230, items=[117]),
#  Row(id=231, items=[18, 83]),
#  Row(id=232, items=[88, 37]),
#  Row(id=233, items=[88, 76]),
#  Row(id=234, items=[70, 18, 83, 38]),
#  Row(id=235, items=[41, 79]),
#  Row(id=236, items=[64, 34, 71, 39, 41, 13, 80, 56, 95]),
#  Row(id=237, items=[56, 44, 4, 119]),
#  Row(id=238, items=[24, 41, 18, 38]),
#  Row(id=239, items=[18]),
#  Row(id=240, items=[117, 38]),
#  Row(id=241, items=[79]),
#  Row(id=242, items=[76]),
#  Row(id=243, items=[80, 114]),
#  Row(id=244, items=[64, 4, 73, 15, 18, 82, 115, 25, 31]),
#  Row(id=245, items=[99, 6, 70, 73, 76, 82, 119]),
#  Row(id=246, items=[34, 76, 83, 51, 118, 26, 92]),
#  Row(id=247, items=[73, 34, 4]),
#  Row(id=248, items=[24, 41, 92, 61]),
#  Row(id=249, items=[6]),
#  Row(id=250, items=[56, 57, 44, 31]),
#  Row(id=251, items=[34, 41, 76, 18, 117, 27]),
#  Row(id=252, items=[27]),
#  Row(id=253, items=[28]),
#  Row(id=254, items=[56, 92, 76]),
#  Row(id=255, items=[10, 117]),
#  Row(id=256, items=[81, 41, 10, 13]),
#  Row(id=257, items=[56]),
#  Row(id=258, items=[96, 64, 56, 83]),
#  Row(id=259, items=[81, 4, 13]),
#  Row(id=260, items=[83, 30]),
#  Row(id=261, items=[56, 41, 83, 8]),
#  Row(id=262, items=[24, 83]),
#  Row(id=263, items=[49]),
#  Row(id=264, items=[109]),
#  Row(id=265, items=[117, 87]),
#  Row(id=266, items=[58]),
#  Row(id=267, items=[18]),
#  Row(id=268, items=[41, 50, 83, 18, 114, 56]),
#  Row(id=269, items=[71, 76, 83, 24, 31]),
#  Row(id=270, items=[6, 39, 91, 79, 56, 27, 92]),
#  Row(id=271, items=[41, 10, 4, 49]),
#  Row(id=272, items=[76, 47, 15, 52, 119, 27]),
#  Row(id=273, items=[71, 74, 47, 80, 84, 117, 90]),
#  Row(id=274, items=[64, 67, 41, 10, 88]),
#  Row(id=275, items=[83, 45]),
#  Row(id=276, items=[41, 16, 18, 21, 117, 28]),
#  Row(id=277, items=[27, 21]),
#  Row(id=278, items=[56]),
#  Row(id=279, items=[41]),
#  Row(id=280, items=[114]),
#  Row(id=281, items=[34]),
#  Row(id=282, items=[88, 76, 45, 63]),
#  Row(id=283, items=[56, 105, 47]),
#  Row(id=284, items=[0, 27]),
#  Row(id=285, items=[18, 27]),
#  Row(id=286, items=[24, 41, 83]),
#  Row(id=287, items=[119]),
#  Row(id=288, items=[18, 58]),
#  Row(id=289, items=[10]),
#  Row(id=290, items=[26, 75, 15, 71]),
#  Row(id=291, items=[18, 58, 98]),
#  Row(id=292, items=[34, 4, 18, 83, 27, 31]),
#  Row(id=293, items=[105, 27, 85, 29]),
#  Row(id=294, items=[67, 41, 105, 76, 108, 78, 13, 79, 50, 83, 56]),
#  Row(id=295, items=[67, 40, 111, 83, 24, 27, 31]),
#  Row(id=296, items=[27]),
#  Row(id=297, items=[76, 13]),
#  Row(id=298, items=[41, 18, 113]),
#  Row(id=299, items=[67, 6, 41, 74, 76, 15, 50, 83, 56]),
#  Row(id=300, items=[4, 103, 13, 79, 58, 27]),
#  Row(id=301, items=[37, 39, 109, 83, 92]),
#  Row(id=302, items=[67, 41, 111, 83, 26]),
#  Row(id=303, items=[1, 74, 13, 109]),
#  Row(id=304, items=[109, 110, 47, 49, 119, 88, 56]),
#  Row(id=305, items=[64, 69, 104, 41, 15, 83, 117, 92]),
#  Row(id=306, items=[0, 25, 18]),
#  Row(id=307, items=[73, 44, 110, 82, 83, 18, 24, 56]),
#  Row(id=308, items=[18, 93]),
#  Row(id=309, items=[41, 117]),
#  Row(id=310, items=[8]),
#  Row(id=311, items=[106]),
#  Row(id=312, items=[76]),
#  Row(id=313, items=[80, 114]),
#  Row(id=314, items=[67, 111]),
#  Row(id=315, items=[56, 37, 95]),
#  Row(id=316, items=[41, 34, 49, 87]),
#  Row(id=317, items=[3, 104, 41, 72, 13, 111, 15, 51, 87, 92]),
#  Row(id=318, items=[56, 26, 83]),
#  Row(id=319, items=[100, 111, 87, 23, 27]),
#  Row(id=320, items=[56, 41, 79]),
#  Row(id=321, items=[50, 108, 87]),
#  Row(id=322, items=[83, 119]),
#  Row(id=323, items=[18, 76]),
#  Row(id=324, items=[34, 68, 41, 74, 13, 18, 56, 31]),
#  Row(id=325, items=[18]),
#  Row(id=326, items=[64, 10, 83, 52]),
#  Row(id=327, items=[6, 104, 82, 56, 58]),
#  Row(id=328, items=[83, 6, 71]),
#  Row(id=329, items=[76]),
#  Row(id=330, items=[56, 26, 27, 47]),
#  Row(id=331, items=[109]),
#  Row(id=332, items=[34, 18]),
#  Row(id=333, items=[64, 38, 39, 104, 56, 90, 29]),
#  Row(id=334, items=[27, 87]),
#  Row(id=335, items=[0, 67, 4, 41, 10, 111, 82, 87, 89, 92]),
#  Row(id=336, items=[114]),
#  Row(id=337, items=[18, 4, 114]),
#  Row(id=338, items=[96, 70, 73, 18, 83, 27]),
#  Row(id=339, items=[115, 29]),
#  Row(id=340, items=[18, 75, 83, 110]),
#  Row(id=341, items=[57, 27, 41]),
#  Row(id=342, items=[17, 59, 39]),
#  Row(id=343, items=[49]),
#  Row(id=344, items=[113, 27, 76, 119]),
#  Row(id=345, items=[56, 26, 76]),
#  Row(id=346, items=[41, 34, 30]),
#  Row(id=347, items=[114]),
#  Row(id=348, items=[114, 45]),
#  Row(id=349, items=[27, 83, 71]),
#  Row(id=350, items=[74, 83, 13, 15]),
#  Row(id=351, items=[83, 76]),
#  Row(id=352, items=[0, 118]),
#  Row(id=353, items=[56, 18, 29]),
#  Row(id=354, items=[0, 90, 76]),
#  Row(id=355, items=[26, 27, 114]),
#  Row(id=356, items=[41, 76, 47, 115, 24, 90]),
#  Row(id=357, items=[0, 2, 37, 44, 111, 47, 18, 114, 26, 27]),
#  Row(id=358, items=[0, 27]),
#  Row(id=359, items=[56, 104]),
#  Row(id=360, items=[98, 18, 83, 117, 24]),
#  Row(id=361, items=[113, 37]),
#  Row(id=362, items=[113, 26, 13]),
#  Row(id=363, items=[10]),
#  Row(id=364, items=[3, 76, 13, 118]),
#  Row(id=365, items=[27]),
#  Row(id=366, items=[56]),
#  Row(id=367, items=[114]),
#  Row(id=368, items=[67, 5, 7, 74, 110, 78, 88, 56]),
#  Row(id=369, items=[83, 117]),
#  Row(id=370, items=[16, 18, 117]),
#  Row(id=371, items=[84]),
#  Row(id=372, items=[18, 115]),
#  Row(id=373, items=[38, 71, 13, 47, 83, 88, 26]),
#  Row(id=374, items=[6, 41, 111, 83, 56]),
#  Row(id=375, items=[100, 110]),
#  Row(id=376, items=[50, 83]),
#  Row(id=377, items=[27]),
#  Row(id=378, items=[78, 47, 50, 18, 117, 119, 56]),
#  Row(id=379, items=[117, 93]),
#  Row(id=380, items=[41, 2, 27, 71]),
#  Row(id=381, items=[0]),
#  Row(id=382, items=[116]),
#  Row(id=383, items=[27]),
#  Row(id=384, items=[37, 76, 82, 24, 57, 56]),
#  Row(id=385, items=[27, 116]),
#  Row(id=386, items=[18, 27, 37, 95]),
#  Row(id=387, items=[76, 21, 102]),
#  Row(id=388, items=[37, 102, 76, 15, 111, 112, 24, 56, 30]),
#  Row(id=389, items=[56, 74, 90, 38]),
#  Row(id=390, items=[18, 77, 71]),
#  Row(id=391, items=[87]),
#  Row(id=392, items=[41, 87]),
#  Row(id=393, items=[4, 104, 73, 10, 75, 41, 13, 76, 87, 24, 90]),
#  Row(id=394, items=[83]),
#  Row(id=395, items=[117, 79, 47]),
#  Row(id=396, items=[113, 18, 85, 117, 56, 27, 92]),
#  Row(id=397, items=[56]),
#  Row(id=398, items=[34, 104, 18, 56, 90]),
#  Row(id=399, items=[56]),
#  Row(id=400, items=[83, 111]),
#  Row(id=401, items=[47, 31]),
#  Row(id=402, items=[106]),
#  Row(id=403, items=[10, 6]),
#  Row(id=404, items=[3]),
#  Row(id=405, items=[41, 27, 79]),
#  Row(id=406, items=[58]),
#  Row(id=407, items=[58]),
#  Row(id=408, items=[101, 70, 104, 12, 78, 114, 83, 27]),
#  Row(id=409, items=[58]),
#  Row(id=410, items=[64, 66, 35, 104, 41]),
#  Row(id=411, items=[18, 79, 47]),
#  Row(id=412, items=[10, 18, 83, 117, 56, 27]),
#  Row(id=413, items=[56]),
#  Row(id=414, items=[64, 67, 104, 117, 24, 56, 28, 93]),
#  Row(id=415, items=[41, 92]),
#  Row(id=416, items=[27]),
#  Row(id=417, items=[14, 47]),
#  Row(id=418, items=[56, 115, 90, 18]),
#  Row(id=419, items=[4, 103, 15, 79, 114, 21]),
#  Row(id=420, items=[57]),
#  Row(id=421, items=[69, 6, 105, 10, 13, 111, 50, 83]),
#  Row(id=422, items=[0, 47, 111, 83, 117, 56]),
#  Row(id=423, items=[58]),
#  Row(id=424, items=[114, 15]),
#  Row(id=425, items=[58]),
#  Row(id=426, items=[79]),
#  Row(id=427, items=[41]),
#  Row(id=428, items=[75, 6, 119]),
#  Row(id=429, items=[56, 90, 104, 68]),
#  Row(id=430, items=[58]),
#  Row(id=431, items=[0, 10, 15, 111, 19]),
#  Row(id=432, items=[64, 41, 110, 111, 18]),
#  Row(id=433, items=[71, 41, 15, 119, 58]),
#  Row(id=434, items=[25, 9]),
#  Row(id=435, items=[41, 112, 50, 114, 87, 56]),
#  Row(id=436, items=[56, 30]),
#  Row(id=437, items=[104, 73, 74, 117, 24, 56]),
#  Row(id=438, items=[18, 34]),
#  Row(id=439, items=[16, 81, 92]),
#  Row(id=440, items=[49]),
#  Row(id=441, items=[64, 49, 34]),
#  Row(id=442, items=[113, 111]),
#  Row(id=443, items=[41, 27]),
#  Row(id=444, items=[114, 83, 30]),
#  Row(id=445, items=[97, 34, 113, 56, 27]),
#  Row(id=446, items=[34, 41, 111, 115, 117, 87, 24, 56, 92]),
#  Row(id=447, items=[76, 14]),
#  Row(id=448, items=[0, 41, 39]),
#  Row(id=449, items=[58]),
#  Row(id=450, items=[58]),
#  Row(id=451, items=[58]),
#  Row(id=452, items=[56, 90, 59]),
#  Row(id=453, items=[26, 37, 104, 74, 18, 83, 56, 90, 27]),
#  Row(id=454, items=[118]),
#  Row(id=455, items=[67, 6, 71, 17, 118, 56]),
#  Row(id=456, items=[96, 41, 10, 79, 114, 83, 117, 56, 27, 92]),
#  Row(id=457, items=[27]),
#  Row(id=458, items=[100, 104, 41, 113, 18, 114, 117, 24]),
#  Row(id=459, items=[83]),
#  Row(id=460, items=[67, 71, 104, 41, 105, 79, 49, 50, 118]),
#  Row(id=461, items=[96, 67, 71, 74, 111, 83, 23, 56]),
#  Row(id=462, items=[96, 6, 110, 111, 79, 18, 56]),
#  Row(id=463, items=[14, 79, 18, 27, 30]),
#  Row(id=464, items=[41]),
#  Row(id=465, items=[34, 58]),
#  Row(id=466, items=[56, 65, 74, 34]),
#  Row(id=467, items=[0, 34, 79, 90, 28]),
#  Row(id=468, items=[67, 71, 41, 75, 15, 18, 117, 24]),
#  Row(id=469, items=[67, 101, 71, 76, 113, 88, 26]),
#  Row(id=470, items=[41, 35]),
#  Row(id=471, items=[64, 0, 71, 104, 15, 18, 24, 56, 93, 62]),
#  Row(id=472, items=[96, 67, 72, 41, 105, 9, 44, 76, 56, 89, 93]),
#  Row(id=473, items=[57, 34, 18]),
#  Row(id=474, items=[41, 83, 67, 71]),
#  Row(id=475, items=[56, 50, 37, 39]),
#  Row(id=476, items=[6, 8, 105, 11, 76, 13, 79, 114, 22, 56, 59]),
#  Row(id=477, items=[34, 67, 69, 71, 41, 10, 43, 47, 56]),
#  Row(id=478, items=[56, 118, 111]),
#  Row(id=479, items=[68, 71, 103, 15, 47, 80, 83, 19, 115, 23, 24, 25]),
#  Row(id=480, items=[18, 117]),
#  Row(id=481, items=[64, 14, 111, 113, 83, 24, 59]),
#  Row(id=482, items=[111, 79, 87]),
#  Row(id=483, items=[34, 67, 76, 113, 83, 119, 56]),
#  Row(id=484, items=[76]),
#  Row(id=485, items=[58]),
#  Row(id=486, items=[41, 58]),
#  Row(id=487, items=[96, 0, 41, 10, 18, 83, 115, 27, 95]),
#  Row(id=488, items=[6, 41, 18, 83, 117]),
#  Row(id=489, items=[10, 76, 21, 87, 27, 92]),
#  Row(id=490, items=[114]),
#  Row(id=491, items=[24, 41, 10, 34]),
#  Row(id=492, items=[27]),
#  Row(id=493, items=[37, 111, 83, 87, 58, 31]),
#  Row(id=494, items=[64, 4, 6, 11, 81, 18, 25, 58, 27, 93]),
#  Row(id=495, items=[27, 76]),
#  Row(id=496, items=[56]),
#  Row(id=497, items=[50]),
#  Row(id=498, items=[24, 83]),
#  Row(id=499, items=[96, 83]),
#  Row(id=500, items=[26, 18, 58]),
#  Row(id=501, items=[79]),
#  Row(id=502, items=[41, 34, 79]),
#  Row(id=503, items=[71, 104, 14, 47, 48, 83, 117, 56]),
#  Row(id=504, items=[56, 41, 118]),
#  Row(id=505, items=[38, 71, 41, 75, 76, 116, 87]),
#  Row(id=506, items=[64, 39, 18, 83, 26, 27]),
#  Row(id=507, items=[114, 119, 71, 87]),
#  Row(id=508, items=[104, 10, 76, 117, 92, 31]),
#  Row(id=509, items=[10]),
#  Row(id=510, items=[56, 41, 10, 27]),
#  Row(id=511, items=[41, 114, 79]),
#  Row(id=512, items=[56, 73, 102]),
#  Row(id=513, items=[41, 111, 83, 27, 92]),
#  Row(id=514, items=[104, 57, 117, 38]),
#  Row(id=515, items=[18]),
#  Row(id=516, items=[67]),
#  Row(id=517, items=[6, 41, 48, 87, 56]),
#  Row(id=518, items=[96, 34, 26, 9, 76, 12, 24, 90, 92]),
#  Row(id=519, items=[56, 57, 74, 64]),
#  Row(id=520, items=[34, 76, 117]),
#  Row(id=521, items=[76, 16, 50, 85, 118, 56, 28]),
#  Row(id=522, items=[34, 36, 4, 39, 41, 47, 117, 87, 56, 26, 27]),
#  Row(id=523, items=[67, 106, 79, 113, 56]),
#  Row(id=524, items=[90, 38, 41, 83, 26]),
#  Row(id=525, items=[41, 10, 76, 56, 92]),
#  Row(id=526, items=[34, 76]),
#  Row(id=527, items=[18, 67, 106]),
#  Row(id=528, items=[5, 10, 44, 15, 111, 83, 56, 28]),
#  Row(id=529, items=[56, 41, 70]),
#  Row(id=530, items=[118]),
#  Row(id=531, items=[41, 59]),
#  Row(id=532, items=[1]),
#  Row(id=533, items=[42, 84, 53, 117, 54]),
#  Row(id=534, items=[104, 41, 24, 27, 28]),
#  Row(id=535, items=[24]),
#  Row(id=536, items=[104, 75, 108]),
#  Row(id=537, items=[88, 41, 67, 31]),
#  Row(id=538, items=[4, 79, 113, 82, 18, 50, 56]),
#  Row(id=539, items=[74, 75, 18, 58, 27]),
#  Row(id=540, items=[33, 104, 13, 50, 83, 117, 54]),
#  Row(id=541, items=[0, 41, 76, 14, 47, 58, 27]),
#  Row(id=542, items=[69, 41, 87, 56, 90]),
#  Row(id=543, items=[13, 76, 117, 79]),
#  Row(id=544, items=[104, 76, 85, 56, 28]),
#  Row(id=545, items=[18, 115]),
#  Row(id=546, items=[18, 67, 87]),
#  Row(id=547, items=[41, 27, 76]),
#  Row(id=548, items=[56, 34, 18, 13]),
#  Row(id=549, items=[41]),
#  Row(id=550, items=[0, 113, 18, 83, 56, 30, 31]),
#  Row(id=551, items=[16, 18, 24, 56, 31]),
#  Row(id=552, items=[105, 76, 13, 113, 83, 117, 87, 92]),
#  Row(id=553, items=[104, 73, 79, 83, 115, 56, 27, 92]),
#  Row(id=554, items=[75, 44, 79, 47]),
#  Row(id=555, items=[41, 79]),
#  Row(id=556, items=[58]),
#  Row(id=557, items=[49, 117]),
#  Row(id=558, items=[64, 49]),
#  Row(id=559, items=[41, 58]),
#  Row(id=560, items=[41]),
#  Row(id=561, items=[57, 41]),
#  Row(id=562, items=[41]),
#  Row(id=563, items=[41, 76]),
#  Row(id=564, items=[114]),
#  Row(id=565, items=[71, 104, 41, 105, 18, 117, 28]),
#  Row(id=566, items=[18, 27]),
#  Row(id=567, items=[34]),
#  Row(id=568, items=[34, 41, 10, 12, 76]),
#  Row(id=569, items=[67, 41, 111, 50, 90]),
#  Row(id=570, items=[41, 2, 18, 79]),
#  Row(id=571, items=[24, 41, 2, 27]),
#  Row(id=572, items=[58, 12, 110]),
#  Row(id=573, items=[0, 4, 114, 117, 119, 56]),
#  Row(id=574, items=[96, 67, 41, 10, 18, 83, 56]),
#  Row(id=575, items=[103, 16, 114, 118, 56, 31]),
#  Row(id=576, items=[38, 75, 83, 19, 87]),
#  Row(id=577, items=[41, 114, 67]),
#  Row(id=578, items=[67]),
#  Row(id=579, items=[114, 92, 103]),
#  Row(id=580, items=[18, 13, 93, 31]),
#  Row(id=581, items=[58]),
#  Row(id=582, items=[100, 111, 114, 83, 56, 92]),
#  Row(id=583, items=[64, 104, 117, 24, 56]),
#  Row(id=584, items=[41, 107, 79, 54, 87, 27]),
#  Row(id=585, items=[24, 72, 92]),
#  Row(id=586, items=[24, 67, 117, 111]),
#  Row(id=587, items=[24, 89, 34, 68]),
#  Row(id=588, items=[117]),
#  Row(id=589, items=[41, 17, 87]),
#  Row(id=590, items=[114]),
#  Row(id=591, items=[27, 19]),
#  Row(id=592, items=[57, 41]),
#  Row(id=593, items=[104, 9, 114]),
#  Row(id=594, items=[26, 107, 109]),
#  Row(id=595, items=[41, 76, 58, 27, 92]),
#  Row(id=596, items=[83]),
#  Row(id=597, items=[57, 18, 29]),
#  Row(id=598, items=[58]),
#  Row(id=599, items=[76]),
#  Row(id=600, items=[88, 64, 56, 83]),
#  Row(id=601, items=[72, 41, 74, 79, 114, 24]),
#  Row(id=602, items=[67, 10, 74, 13, 18, 114, 56]),
#  Row(id=603, items=[110, 15, 47, 18, 83, 61]),
#  Row(id=604, items=[105, 36]),
#  Row(id=605, items=[41, 27, 49]),
#  Row(id=606, items=[56]),
#  Row(id=607, items=[56, 74, 64, 111]),
#  Row(id=608, items=[41, 79]),
#  Row(id=609, items=[66, 8, 16, 83, 19]),
#  Row(id=610, items=[64, 100, 4, 71, 41, 112, 87, 26]),
#  Row(id=611, items=[109, 110, 111, 15, 114, 52, 117, 27, 94]),
#  Row(id=612, items=[89, 83, 31]),
#  Row(id=613, items=[24, 41, 56]),
#  Row(id=614, items=[102, 10, 43, 83, 26]),
#  Row(id=615, items=[67, 39, 9, 83, 87, 56]),
#  Row(id=616, items=[56, 50, 83, 114]),
#  Row(id=617, items=[104]),
#  Row(id=618, items=[83, 67, 92]),
#  Row(id=619, items=[58, 21, 103]),
#  Row(id=620, items=[71, 39, 104, 15, 18, 117, 88, 56, 31]),
#  Row(id=621, items=[75, 110, 14, 50, 18, 117, 56, 29]),
#  Row(id=622, items=[96, 41, 27, 49]),
#  Row(id=623, items=[56, 29]),
#  Row(id=624, items=[58]),
#  Row(id=625, items=[1, 41, 75, 76, 14, 18]),
#  Row(id=626, items=[41, 30, 79]),
#  Row(id=627, items=[18, 45]),
#  Row(id=628, items=[27, 83, 76, 111]),
#  Row(id=629, items=[34]),
#  Row(id=630, items=[6, 41, 10, 107, 113, 50, 18, 87, 56]),
#  Row(id=631, items=[64, 7, 18, 19, 56]),
#  Row(id=632, items=[72, 44]),
#  Row(id=633, items=[71, 41, 50, 19, 18, 117, 24, 27]),
#  Row(id=634, items=[56, 41, 117, 111]),
#  Row(id=635, items=[114]),
#  Row(id=636, items=[58, 87]),
#  Row(id=637, items=[56, 18, 76, 111]),
#  Row(id=638, items=[64, 75, 13, 79, 18, 83, 88, 27]),
#  Row(id=639, items=[6]),
#  Row(id=640, items=[72, 41, 14, 47, 79, 50, 24, 56]),
#  Row(id=641, items=[70, 74, 87, 57, 95]),
#  Row(id=642, items=[5, 49, 50, 87, 92]),
#  Row(id=643, items=[27, 79]),
#  Row(id=644, items=[109]),
#  Row(id=645, items=[34, 67, 76, 15, 113, 56]),
#  Row(id=646, items=[34, 3, 79, 18, 56]),
#  Row(id=647, items=[64, 104, 74, 18, 117, 56, 89, 26]),
#  Row(id=648, items=[56, 21]),
#  Row(id=649, items=[114]),
#  Row(id=650, items=[74, 75, 113, 50, 19]),
#  Row(id=651, items=[9, 111]),
#  Row(id=652, items=[58]),
#  Row(id=653, items=[111, 82, 117, 26, 29]),
#  Row(id=654, items=[24, 41, 104, 79]),
#  Row(id=655, items=[67, 73, 10, 76, 12, 111, 18, 83, 82, 55, 56]),
#  Row(id=656, items=[34, 71, 41, 105, 12, 79, 50, 19, 56]),
#  Row(id=657, items=[96, 64, 67, 70, 9, 76, 47, 50, 83, 55, 24, 90]),
#  Row(id=658, items=[41, 26, 2]),
#  Row(id=659, items=[71, 9, 18, 114, 56, 93]),
#  Row(id=660, items=[49]),
#  Row(id=661, items=[96, 4, 41, 10, 79, 50, 83, 56, 57]),
#  Row(id=662, items=[24, 90, 71]),
#  Row(id=663, items=[67, 110, 111, 15, 87, 24, 56]),
#  Row(id=664, items=[56, 71]),
#  Row(id=665, items=[104, 106, 111, 114, 83, 87]),
#  Row(id=666, items=[99, 71, 104, 41, 17, 82, 117, 56, 58, 31]),
#  Row(id=667, items=[10, 92]),
#  Row(id=668, items=[79]),
#  Row(id=669, items=[56, 117]),
#  Row(id=670, items=[117]),
#  Row(id=671, items=[18]),
#  Row(id=672, items=[88, 10, 56, 64]),
#  Row(id=673, items=[56, 41, 34, 110]),
#  Row(id=674, items=[27, 87]),
#  Row(id=675, items=[64, 71, 76, 110, 16, 18, 83, 84, 56, 89, 26, 27]),
#  Row(id=676, items=[4, 76, 15, 117, 56, 58]),
#  Row(id=677, items=[64, 83]),
#  Row(id=678, items=[83, 67]),
#  Row(id=679, items=[104, 40, 10, 15, 79, 83, 56, 26]),
#  Row(id=680, items=[64, 4, 73, 106, 111, 18, 117, 24, 56, 88, 28]),
#  Row(id=681, items=[76]),
#  Row(id=682, items=[5, 72, 41, 74, 13, 79, 18, 83, 92]),
#  Row(id=683, items=[96, 64, 111, 16, 57, 26, 95]),
#  Row(id=684, items=[64, 76, 47, 50, 88, 56]),
#  Row(id=685, items=[0, 70]),
#  Row(id=686, items=[64]),
#  Row(id=687, items=[67, 10, 76, 111, 114]),
#  Row(id=688, items=[67, 73, 41, 76, 111, 113, 18, 83, 114, 117, 119, 24, 56, 93]),
#  Row(id=689, items=[110, 23]),
#  Row(id=690, items=[26]),
#  Row(id=691, items=[67, 41, 28, 110, 111, 109, 117, 87, 56, 27, 92, 29]),
#  Row(id=692, items=[88, 40, 45, 15]),
#  Row(id=693, items=[18, 27, 4, 21]),
#  Row(id=694, items=[71, 104, 60, 111, 18, 88, 57, 92]),
#  Row(id=695, items=[10, 75, 47, 16, 79, 56, 27]),
#  Row(id=696, items=[41, 109]),
#  Row(id=697, items=[24, 41, 71, 87]),
#  Row(id=698, items=[41, 106, 92]),
#  Row(id=699, items=[64, 34, 26, 71, 39, 28, 110, 112, 24, 56, 88, 92]),
#  Row(id=700, items=[56, 26, 67, 111]),
#  Row(id=701, items=[47]),
#  Row(id=702, items=[26, 13]),
#  Row(id=703, items=[88, 64]),
#  Row(id=704, items=[57, 76, 117]),
#  Row(id=705, items=[74, 67]),
#  Row(id=706, items=[114, 76]),
#  Row(id=707, items=[38, 104, 76, 117, 28]),
#  Row(id=708, items=[8, 58, 67]),
#  Row(id=709, items=[64, 89, 105, 74, 10, 79, 88, 57, 27]),
#  Row(id=710, items=[37]),
#  Row(id=711, items=[97, 37, 41, 47, 19, 56]),
#  Row(id=712, items=[48, 107]),
#  Row(id=713, items=[41, 76, 111, 16, 18, 117, 31]),
#  Row(id=714, items=[6, 75, 79, 18, 58, 27]),
#  Row(id=715, items=[18, 83, 42]),
#  Row(id=716, items=[58]),
#  Row(id=717, items=[4, 70, 41, 113, 83, 56]),
#  Row(id=718, items=[36, 74, 15, 79, 113, 18, 114, 56, 30]),
#  Row(id=719, items=[0, 83]),
#  Row(id=720, items=[24, 56]),
#  Row(id=721, items=[56, 79, 63]),
#  Row(id=722, items=[34, 67, 6, 13, 88]),
#  Row(id=723, items=[41, 19, 119, 27, 92]),
#  Row(id=724, items=[56, 41, 10]),
#  Row(id=725, items=[41, 27]),
#  Row(id=726, items=[24, 90, 83, 71]),
#  Row(id=727, items=[10, 76, 18, 56, 27, 28]),
#  Row(id=728, items=[34, 27, 114]),
#  Row(id=729, items=[33, 2, 73, 15, 83, 117, 55, 24, 56]),
#  Row(id=730, items=[34, 28, 79]),
#  Row(id=731, items=[27]),
#  Row(id=732, items=[119]),
#  Row(id=733, items=[0, 104, 76, 79, 18, 56, 89, 26]),
#  Row(id=734, items=[64, 111]),
#  Row(id=735, items=[58, 27, 76]),
#  Row(id=736, items=[0, 69, 104, 81, 50, 18, 58]),
#  Row(id=737, items=[4, 47, 18, 114, 27]),
#  Row(id=738, items=[9, 110]),
#  Row(id=739, items=[109, 15, 111, 18, 24, 25]),
#  Row(id=740, items=[64, 34, 67, 37, 39, 10, 18, 19, 117]),
#  Row(id=741, items=[71, 74, 75, 14, 113, 114, 58, 27]),
#  Row(id=742, items=[0, 41, 57, 27, 63]),
#  Row(id=743, items=[41, 27, 92]),
#  Row(id=744, items=[4, 71, 41, 18, 117, 56, 27, 92]),
#  Row(id=745, items=[5, 76, 111, 18, 117, 56, 26]),
#  Row(id=746, items=[56, 26]),
#  Row(id=747, items=[34, 41, 111, 83, 117, 87]),
#  Row(id=748, items=[27, 76]),
#  Row(id=749, items=[114, 27]),
#  Row(id=750, items=[46, 87]),
#  Row(id=751, items=[64, 79, 118, 23, 88, 56]),
#  Row(id=752, items=[58]),
#  Row(id=753, items=[37, 74, 87, 27, 62]),
#  Row(id=754, items=[6, 104, 105, 17, 18, 82, 87, 56, 89, 26]),
#  Row(id=755, items=[41, 87]),
#  Row(id=756, items=[79]),
#  Row(id=757, items=[5, 79]),
#  Row(id=758, items=[24, 79]),
#  Row(id=759, items=[67, 41, 9, 79, 19, 117, 88, 56]),
#  Row(id=760, items=[9, 106]),
#  Row(id=761, items=[81, 84]),
#  Row(id=762, items=[4, 76, 71]),
#  Row(id=763, items=[114, 93, 31]),
#  Row(id=764, items=[56, 34, 12, 118]),
#  Row(id=765, items=[3]),
#  Row(id=766, items=[6]),
#  Row(id=767, items=[56, 21, 83, 37]),
#  Row(id=768, items=[56, 41, 76]),
#  Row(id=769, items=[4, 73, 74, 76, 19, 24, 27]),
#  Row(id=770, items=[64, 34, 109, 18, 83, 19, 117, 24, 56, 88, 29]),
#  Row(id=771, items=[64, 37, 71, 9, 74, 18, 83, 21]),
#  Row(id=772, items=[83, 21]),
#  Row(id=773, items=[18, 92, 30]),
#  Row(id=774, items=[56, 64, 112]),
#  Row(id=775, items=[41, 76]),
#  Row(id=776, items=[13]),
#  Row(id=777, items=[109, 79]),
#  Row(id=778, items=[64, 0, 104, 10, 79, 89]),
#  Row(id=779, items=[56, 70, 79]),
#  Row(id=780, items=[37, 41, 10, 76, 18, 56, 29, 31]),
#  Row(id=781, items=[37, 28, 47, 92, 94]),
#  Row(id=782, items=[42, 99, 14]),
#  Row(id=783, items=[68, 37, 10, 111, 47, 113, 83, 24, 27, 62]),
#  Row(id=784, items=[56, 83, 117]),
#  Row(id=785, items=[10]),
#  Row(id=786, items=[109]),
#  Row(id=787, items=[24, 105, 85]),
#  Row(id=788, items=[34, 71, 47, 52, 117, 87, 56, 28]),
#  Row(id=789, items=[59, 107, 18, 82, 91]),
#  Row(id=790, items=[83, 5, 38, 119]),
#  Row(id=791, items=[24, 34, 10, 58]),
#  Row(id=792, items=[42, 75, 76, 106, 27]),
#  Row(id=793, items=[67]),
#  Row(id=794, items=[2, 104, 117, 26, 62]),
#  Row(id=795, items=[71, 15, 47, 114, 83, 117, 119, 56, 29]),
#  Row(id=796, items=[0, 113, 114, 117]),
#  Row(id=797, items=[80, 114, 30]),
#  Row(id=798, items=[19]),
#  Row(id=799, items=[27, 74, 83]),
#  Row(id=800, items=[64, 34, 26, 71, 10, 15, 83, 117, 88, 56, 92]),
#  Row(id=801, items=[7, 74, 75, 111, 113, 18, 83, 117, 87, 24]),
#  Row(id=802, items=[97, 41, 76, 18, 114, 87, 31]),
#  Row(id=803, items=[10, 76, 111, 117, 90, 29]),
#  Row(id=804, items=[56, 76, 118, 87]),
#  Row(id=805, items=[56, 79]),
#  Row(id=806, items=[10, 3, 13]),
#  Row(id=807, items=[7, 105, 10, 107, 76, 110, 27, 29, 95]),
#  Row(id=808, items=[64, 34, 36, 71, 104, 105, 83, 117, 56, 26]),
#  Row(id=809, items=[26, 43, 50]),
#  Row(id=810, items=[1, 100, 70, 104, 9, 10, 76, 118, 54, 92, 63]),
#  Row(id=811, items=[31, 71]),
#  Row(id=812, items=[64, 83, 69]),
#  Row(id=813, items=[109]),
#  Row(id=814, items=[67, 41, 74, 109, 79]),
#  Row(id=815, items=[102, 72, 74, 50, 83, 117, 24, 89]),
#  Row(id=816, items=[10, 27, 13, 31]),
#  Row(id=817, items=[100, 9, 76, 111, 112, 19, 117, 24, 90, 93]),
#  Row(id=818, items=[64, 58, 76, 18, 26]),
#  Row(id=819, items=[73, 10, 41, 13, 111, 47, 18, 83, 84, 88]),
#  Row(id=820, items=[41, 14]),
#  Row(id=821, items=[109, 14]),
#  Row(id=822, items=[16, 76, 47]),
#  Row(id=823, items=[56, 0, 18, 82]),
#  Row(id=824, items=[56]),
#  Row(id=825, items=[88, 117, 38, 71]),
#  Row(id=826, items=[32, 67, 73, 10, 41, 111, 19, 83, 55, 28, 31]),
#  Row(id=827, items=[71, 9, 74, 111, 19, 56]),
#  Row(id=828, items=[56, 82]),
#  Row(id=829, items=[10]),
#  Row(id=830, items=[56, 37]),
#  Row(id=831, items=[81, 10, 92, 111]),
#  Row(id=832, items=[27, 66, 19, 95]),
#  Row(id=833, items=[113]),
#  Row(id=834, items=[105, 9, 111, 82, 83, 50, 119, 26]),
#  Row(id=835, items=[18, 75]),
#  Row(id=836, items=[31]),
#  Row(id=837, items=[0, 67, 106, 76, 18]),
#  Row(id=838, items=[56, 41, 74, 114]),
#  Row(id=839, items=[58, 115, 76, 106]),
#  Row(id=840, items=[50, 117]),
#  Row(id=841, items=[64, 4, 10, 13, 47, 112, 79, 50, 117, 85, 89, 26, 27]),
#  Row(id=842, items=[104, 106, 76, 79, 49, 117, 90, 29]),
#  Row(id=843, items=[96, 105, 111, 18, 56]),
#  Row(id=844, items=[0, 114, 76]),
#  Row(id=845, items=[18]),
#  Row(id=846, items=[80, 114]),
#  Row(id=847, items=[64, 45, 47, 82, 56, 92]),
#  Row(id=848, items=[76]),
#  Row(id=849, items=[10, 74, 16, 49, 83, 117, 93]),
#  Row(id=850, items=[83, 52, 21, 87]),
#  Row(id=851, items=[109]),
#  Row(id=852, items=[2, 111, 50, 83, 58]),
#  Row(id=853, items=[97, 37, 70, 10, 79, 83, 19, 119, 24, 92]),
#  Row(id=854, items=[111]),
#  Row(id=855, items=[62]),
#  Row(id=856, items=[0, 37, 113, 114, 24, 56]),
#  Row(id=857, items=[41, 75, 108, 76, 47, 79, 19, 115, 117, 55]),
#  Row(id=858, items=[56, 34]),
#  Row(id=859, items=[10, 76, 47, 113, 50, 117, 87, 56, 58]),
#  Row(id=860, items=[18, 27, 29]),
#  Row(id=861, items=[76]),
#  Row(id=862, items=[41, 18, 42]),
#  Row(id=863, items=[74, 27, 109, 63]),
#  Row(id=864, items=[66, 69, 41, 114, 56]),
#  Row(id=865, items=[113]),
#  Row(id=866, items=[58, 5, 30]),
#  Row(id=867, items=[0, 27]),
#  Row(id=868, items=[56, 15]),
#  Row(id=869, items=[64]),
#  Row(id=870, items=[34, 37, 104, 40, 75, 111, 81, 117, 87, 90, 95]),
#  Row(id=871, items=[79, 18, 83, 19, 20, 56]),
#  Row(id=872, items=[64, 97, 34, 104, 41, 10, 75, 28, 18, 19, 117, 57, 92]),
#  Row(id=873, items=[37, 71, 76, 80, 49]),
#  Row(id=874, items=[0, 39, 73, 10, 109, 47, 18, 117]),
#  Row(id=875, items=[21]),
#  Row(id=876, items=[67]),
#  Row(id=877, items=[0, 97, 34, 67, 37, 41, 111, 82, 19, 85, 24, 90, 27]),
#  Row(id=878, items=[14, 114, 83, 52, 85, 117, 56]),
#  Row(id=879, items=[34, 102, 39, 41, 10, 14, 49, 83, 87, 92]),
#  Row(id=880, items=[59]),
#  Row(id=881, items=[68, 37, 28, 112, 83, 23, 56, 92]),
#  Row(id=882, items=[14, 47, 18, 115, 21, 27]),
#  Row(id=883, items=[52]),
#  Row(id=884, items=[18, 27]),
#  Row(id=885, items=[18, 27, 21]),
#  Row(id=886, items=[65, 34, 68, 50, 87, 24, 89, 26, 29]),
#  Row(id=887, items=[64, 57, 103]),
#  Row(id=888, items=[71, 87]),
#  Row(id=889, items=[0, 18, 83, 106]),
#  Row(id=890, items=[71, 75, 107, 76, 18, 56, 29]),
#  Row(id=891, items=[76, 109, 95]),
#  Row(id=892, items=[106]),
#  Row(id=893, items=[100, 7, 9, 75, 15, 50, 18, 119, 117, 118, 87, 27, 93]),
#  Row(id=894, items=[74]),
#  Row(id=895, items=[10, 75, 36, 95]),
#  Row(id=896, items=[103, 10, 75, 76, 79, 113, 58, 27]),
#  Row(id=897, items=[71, 75, 18, 50, 114]),
#  Row(id=898, items=[37, 6, 113, 18, 83, 50, 117, 85, 24, 92, 31]),
#  Row(id=899, items=[34, 8, 41, 10, 11, 111, 18, 83, 87]),
#  Row(id=900, items=[1, 71, 75, 76, 81, 117, 26]),
#  Row(id=901, items=[97, 37, 39, 72, 76, 46, 47, 18, 21, 56, 27]),
#  Row(id=902, items=[18, 58]),
#  Row(id=903, items=[115, 46]),
#  Row(id=904, items=[90, 114, 83, 24, 26, 27]),
#  Row(id=905, items=[34, 70, 41, 10, 75, 44, 76, 17, 87, 92]),
#  Row(id=906, items=[36, 6, 71, 41, 106, 110]),
#  Row(id=907, items=[115, 27]),
#  Row(id=908, items=[0, 41, 107, 111, 18, 92]),
#  Row(id=909, items=[30]),
#  Row(id=910, items=[40, 75]),
#  Row(id=911, items=[113]),
#  Row(id=912, items=[72]),
#  Row(id=913, items=[56, 0, 27, 76]),
#  Row(id=914, items=[81, 76, 85]),
#  Row(id=915, items=[100, 71, 10, 18, 83, 114, 58, 27, 95]),
#  Row(id=916, items=[96, 110, 50, 83, 18, 119, 26]),
#  Row(id=917, items=[41]),
#  Row(id=918, items=[64, 42, 47, 111, 119]),
#  Row(id=919, items=[64, 104, 114, 83, 24, 56]),
#  Row(id=920, items=[105, 113, 114, 26, 27]),
#  Row(id=921, items=[76]),
#  Row(id=922, items=[0, 113, 114, 19]),
#  Row(id=923, items=[97, 37, 39, 115, 24, 26]),
#  Row(id=924, items=[111]),
#  Row(id=925, items=[0, 4, 76, 109, 58]),
#  Row(id=926, items=[4, 18, 83, 114, 24]),
#  Row(id=927, items=[27, 83, 94, 47]),
#  Row(id=928, items=[29]),
#  Row(id=929, items=[84]),
#  Row(id=930, items=[105, 83, 108, 117]),
#  Row(id=931, items=[0]),
#  Row(id=932, items=[83]),
#  Row(id=933, items=[0]),
#  Row(id=934, items=[75, 117, 58, 27, 29]),
#  Row(id=935, items=[101, 41, 47, 79, 87, 24, 26]),
#  Row(id=936, items=[26, 71, 28, 18, 117, 57, 90, 27, 92, 63]),
#  Row(id=937, items=[34, 107, 50, 114, 117, 27, 92]),
#  Row(id=938, items=[64, 34, 47, 113, 18, 83, 117, 118, 90]),
#  Row(id=939, items=[97, 37, 6, 39, 41, 10, 76, 15, 83, 31]),
#  Row(id=940, items=[117, 79]),
#  Row(id=941, items=[71, 104, 18, 19, 95]),
#  Row(id=942, items=[26, 83]),
#  Row(id=943, items=[74, 76, 5, 70]),
#  Row(id=944, items=[2, 37, 39, 105, 109, 78, 19]),
#  Row(id=945, items=[34]),
#  Row(id=946, items=[18, 3, 30, 71]),
#  Row(id=947, items=[3]),
#  Row(id=948, items=[37, 29]),
#  Row(id=949, items=[24, 90, 14, 71]),
#  Row(id=950, items=[27]),
#  Row(id=951, items=[21]),
#  Row(id=952, items=[114, 27, 28, 111]),
#  Row(id=953, items=[74, 83]),
#  Row(id=954, items=[56, 75, 47, 87]),
#  Row(id=955, items=[76, 83, 115, 24, 27]),
#  Row(id=956, items=[96, 103, 76, 113, 18, 83, 58, 59, 92]),
#  Row(id=957, items=[69, 74, 76, 47, 82, 83, 18, 117, 119, 24, 89, 58, 27, 29]),
#  Row(id=958, items=[7, 71, 76, 113, 90, 92]),
#  Row(id=959, items=[10, 19]),
#  Row(id=960, items=[34, 19, 76, 119]),
#  Row(id=961, items=[97, 98, 18, 83, 117, 22]),
#  Row(id=962, items=[9]),
#  Row(id=963, items=[9, 18]),
#  Row(id=964, items=[27, 81, 75, 4]),
#  Row(id=965, items=[106, 18, 115, 21, 27]),
#  Row(id=966, items=[41, 58, 59]),
#  Row(id=967, items=[106]),
#  Row(id=968, items=[64, 67, 37, 38, 10, 47, 114, 83, 117, 26]),
#  Row(id=969, items=[24, 82, 18]),
#  Row(id=970, items=[67, 41, 111, 18, 83, 117, 89]),
#  Row(id=971, items=[0, 41]),
#  Row(id=972, items=[64, 69, 111, 114, 88]),
#  Row(id=973, items=[6, 41, 105, 13, 23, 56, 91, 92]),
#  Row(id=974, items=[64, 67, 104, 74, 18, 56]),
#  Row(id=975, items=[97, 34, 71, 41, 15, 47, 21, 56, 26, 92]),
#  Row(id=976, items=[76]),
#  Row(id=977, items=[58]),
#  Row(id=978, items=[58, 27]),
#  Row(id=979, items=[41, 75, 117]),
#  Row(id=980, items=[41, 30, 79]),
#  Row(id=981, items=[41, 76]),
#  Row(id=982, items=[56, 113]),
#  Row(id=983, items=[34, 71, 113, 19, 24, 56]),
#  Row(id=984, items=[113, 10]),
#  Row(id=985, items=[64, 101, 105, 75, 15, 47, 50, 83, 24]),
#  Row(id=986, items=[76]),
#  Row(id=987, items=[41, 114, 21, 39]),
#  Row(id=988, items=[104, 18, 83, 117, 23]),
#  Row(id=989, items=[64, 38, 104, 56, 92]),
#  Row(id=990, items=[74, 79, 50, 56, 58, 27]),
#  Row(id=991, items=[64, 27, 117, 71]),
#  Row(id=992, items=[34, 10, 13, 24, 56]),
#  Row(id=993, items=[26, 83, 117]),
#  Row(id=994, items=[74, 10, 14, 56, 26, 27]),
#  Row(id=995, items=[41, 9, 111, 117, 56]),
#  Row(id=996, items=[76, 63, 71]),
#  Row(id=997, items=[47]),
#  Row(id=998, items=[67, 109, 85, 24, 56]),
#  Row(id=999, items=[2, 34, 37, 41, 76, 13, 83, 117, 87, 90, 27, 95]),
#  ...]

# %%
fpGrowth = FPGrowth(itemsCol="items", minSupport=0.01, minConfidence=0.3)
model = fpGrowth.fit(market)

# %%
# Display frequent itemsets.
model.freqItemsets.show()
# Out:
# +-------------+----+
# |        items|freq|
# +-------------+----+
# |        [119]| 243|
# |        [112]|  90|
# |         [85]| 193|
# |     [85, 56]|  77|
# |         [24]| 715|
# |     [24, 83]| 209|
# | [24, 83, 56]|  90|
# |     [24, 76]| 108|
# |     [24, 18]| 172|
# |    [24, 111]| 127|
# |     [24, 41]| 163|
# |     [24, 27]| 143|
# |    [24, 117]| 177|
# |[24, 117, 56]|  83|
# |     [24, 56]| 268|
# |        [118]| 139|
# |         [26]| 450|
# |     [26, 83]| 129|
# |     [26, 76]|  89|
# |     [26, 18]| 110|
# +-------------+----+
# only showing top 20 rows

# %%
# Display generated association rules.
model.associationRules.show()
# Out:
# +----------+----------+-------------------+
# |antecedent|consequent|         confidence|
# +----------+----------+-------------------+
# |  [64, 56]|      [83]| 0.3719806763285024|
# |  [10, 56]|      [83]|0.33992094861660077|
# | [117, 56]|      [83]| 0.3277777777777778|
# | [111, 83]|      [56]|0.43537414965986393|
# |      [50]|      [83]|0.31070496083550914|
# |      [50]|      [56]|0.39425587467362927|
# |      [26]|      [56]|               0.38|
# | [117, 41]|      [56]|0.42424242424242425|
# |  [10, 83]|      [56]|  0.455026455026455|
# |      [15]|      [83]| 0.3166144200626959|
# |      [15]|      [56]| 0.4012539184952978|
# | [111, 56]|      [83]| 0.4169381107491857|
# |  [24, 83]|      [56]|  0.430622009569378|
# |       [4]|      [56]|0.30959752321981426|
# |      [37]|      [56]|0.31741573033707865|
# |      [87]|      [41]|0.31130063965884863|
# |      [87]|      [56]| 0.3070362473347548|
# |  [83, 41]|      [56]| 0.3905109489051095|
# |      [29]|      [56]|              0.348|
# |      [83]|      [56]| 0.3430321592649311|
# +----------+----------+-------------------+
# only showing top 20 rows

# %%
model.transform(market).show()
# Out:
# +---+--------------------+----------+
# | id|               items|prediction|
# +---+--------------------+----------+
# |  0|[64, 37, 70, 71, ...|      [83]|
# |  1|        [41, 92, 38]|        []|
# |  2|                [33]|        []|
# |  3|            [29, 87]|  [41, 56]|
# |  4|[76, 113, 117, 56...|      [83]|
# |  5|                [79]|      [56]|
# |  6|            [88, 27]|        []|
# |  7|      [104, 89, 103]| [117, 56]|
# |  8|        [24, 83, 76]|      [56]|
# |  9|                [27]|        []|
# | 10|             [8, 41]|        []|
# | 11|                [58]|        []|
# | 12|[41, 50, 87, 56, 92]|      [83]|
# | 13|         [0, 58, 83]|      [56]|
# | 14|            [56, 15]|      [83]|
# | 15|                [56]|        []|
# | 16|[37, 71, 105, 79,...|  [83, 56]|
# | 17|            [41, 87]|      [56]|
# | 18|[26, 39, 41, 15, ...|        []|
# | 19|[37, 38, 117, 118...|      [56]|
# +---+--------------------+----------+
# only showing top 20 rows

# %%
new=sqlContext.createDataFrame([
    (4, [26])
], ["id", "items"])

result=model.transform(new)

# %%
result.show()
# Out:
# +---+-----+----------+
# | id|items|prediction|
# +---+-----+----------+
# |  4| [26]|      [56]|
# +---+-----+----------+
